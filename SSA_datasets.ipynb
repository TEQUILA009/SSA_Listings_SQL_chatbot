# %% [markdown]
# <a href="https://colab.research.google.com/github/TEQUILA009/SSA_Listings_SQL_chatbot/blob/main/SSA_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/Administrative Law Judge Disposition Data.csv')

# %%
df2=pd.read_csv('/content/Average Wait Time Until Hearing Held Report.csv')

# %%
df3=pd.read_csv('/content/National Ranking Report.csv')

# %%
df4=pd.read_csv('/content/hearing office workload.csv')

# %%
df5=pd.read_csv('/content/hearings & appels ptime.csv')

# %%
df1 =df1.iloc[1: , :]

# %%
df2 =df2.iloc[1: , :]

# %%
df3 =df3.iloc[1: , :]

# %%
df4 =df4.iloc[1: , :]

# %%
df5 =df5.iloc[1: , :]

# %%
df1
# Out:
#      RPTG_PRD_ENDT  FULLY_FAVORABLE               JUDGE           OFFICE  \
# 1       04/26/2024            133.0  Abbondondelo, Mary       SHREVEPORT
# 2       04/26/2024             68.0        Able, Devona       ALEXANDRIA
# 3       04/26/2024             76.0    Adamo, Genevieve        CLEVELAND
# 4       04/26/2024             89.0      Adams, Rebecca  FAYETTEVILLE NC
# 5       04/26/2024            143.0     Addison, Andrea      JERSEY CITY
# ...            ...              ...                 ...              ...
# 1394    04/26/2024              2.0     Zanotto, Sharon       HARRISBURG
# 1395    04/26/2024             65.0     Zeidman, Arthur        LAS VEGAS
# 1396    04/26/2024              2.0     Zeidman, Arthur          OAKLAND
# 1397    04/26/2024             78.0    Zimmerman, Stacy           ORANGE
# 1398    04/26/2024             95.0   Zuber, William C.       LOUISVILLE
#
#       PARTIALLY_FAVORABLE  REGION  TOTAL_ALJ_DIPOSITIONS_ACROSS_ALL_OFFICES  \
# ...

# %%
df2
# Out:
#       MONTH HEARING_OFFICE_NAME  HEARING_OFFICE_TIMES_IN_MONTHS  HO_CODE  \
# 1    202404            AKRON OH                             7.0   5380.0
# 2    202404              ALBANY                             9.0   5024.0
# 3    202404         ALBUQUERQUE                             9.0   5077.0
# 4    202404          ALEXANDRIA                             8.0   5075.0
# 5    202404    ATLANTA DOWNTOWN                             8.0   5039.0
# ..      ...                 ...                             ...      ...
# 163  202404       VALPARAISO IN                             7.5   5365.0
# 164  202404          WASHINGTON                            11.0   5029.0
# 165  202404        WHITE PLAINS                             8.0   5135.0
# 166  202404             WICHITA                             8.0   5127.0
# 167  202404        WILKES BARRE                             9.0   5037.0
#
#      REGION SITE_CODE
# 1       5.0       T1P
# 2       2.0       X37
# ...

# %%
df3
# Out:
#     RPTG_PRD_ENDT  ALJ_DISPS_PER_DAY_PER_ALJ        HEARING_OFFICE   RANK  \
# 1      04/26/2024                       2.29           COLUMBIA MO    1.0
# 2      04/26/2024                       2.26           ALBUQUERQUE    2.0
# 3      04/26/2024                       2.26             JOHNSTOWN    2.0
# 4      04/26/2024                       2.15         CHARLESTON WV    4.0
# 5      04/26/2024                       2.15      DALLAS NORTH OHO    4.0
# ..            ...                        ...                   ...    ...
# 158    04/26/2024                       1.10  SPECIAL REVIEW CADRE  157.0
# 159    04/26/2024                       1.09              SAN JUAN  159.0
# 160    04/26/2024                       1.08             MIAMI OHO  160.0
# 161    04/26/2024                       1.02              NEW YORK  161.0
# 162    04/26/2024                       0.97              FLORENCE  162.0
#
#      REGION  WORKDAYS
# 1       7.0     143.0
# 2       6.0     143.0
# ...

# %%
df4
# Out:
#     RPTG_PRD_ENDT  AVERAGE_PROCESSING_TIME  CASES_PENDING  DISPOSITIONS  \
# 1      04/26/2024                    249.0         2177.0        2057.0
# 2      04/26/2024                    361.0         2474.0        1737.0
# 3      04/26/2024                    309.0         2699.0        1104.0
# 4      04/26/2024                    356.0         1502.0        1774.0
# 5      04/26/2024                      NaN            0.0           0.0
# ..            ...                      ...            ...           ...
# 167    04/26/2024                    285.0         1310.0        1191.0
# 168    04/26/2024                    450.0         2098.0        1654.0
# 169    04/26/2024                    294.0         1659.0        1270.0
# 170    04/26/2024                    359.0          941.0         666.0
# 171    04/26/2024                    396.0         3123.0        1933.0
#
#                      OFFICE  RECEIPTS  REGION
# 1                  AKRON OH    2024.0     5.0
# ...

# %%
df5
# Out:
#     RPTG_PRD_ENDT  AVERAGE_PROCESSING_TIME          HEARING_OFFICE   RANK  \
# 1      04/26/2024                    154.0  NATL ADJUDICATION TEAM    1.0
# 2      04/26/2024                    241.0                  TUPELO    2.0
# 3      04/26/2024                    246.0              EVANSVILLE    3.0
# 4      04/26/2024                    249.0           HOUSTON NORTH    4.0
# 5      04/26/2024                    249.0                AKRON OH    4.0
# ..            ...                      ...                     ...    ...
# 159    04/26/2024                    563.0                 OAKLAND  159.0
# 160    04/26/2024                    575.0                SAN JUAN  160.0
# 161    04/26/2024                    576.0       PHILADELPHIA EAST  161.0
# 162    04/26/2024                    709.0                   PONCE  162.0
# 163    04/26/2024                    719.0           SANTA BARBARA  163.0
#
#      REGION  WORKDAYS
# 1      12.0     143.0
# 2       4.0     143.0
# ...

# %%
df1 = df1.rename(columns={'OFFICE': 'HEARING_OFFICE'})

# %%
df2 = df2.rename(columns={'HEARING_OFFICE_NAME': 'HEARING_OFFICE'})
df2 = df2.drop('REGION', axis=1)
df2 = df2.drop('MONTH', axis=1)

# %%
df3 = df3.rename(columns={'RANK': 'DISP_RANK'})
df3 = df3.drop('REGION', axis=1)

# %%
df4 = df4.rename(columns={'OFFICE': 'HEARING_OFFICE'})
df4 = df4.drop('REGION', axis=1)
df4 = df4.drop('RPTG_PRD_ENDT', axis=1)

# %%
df5 = df5.rename(columns={'RANK': 'AVG_Ptime_RANK'})
df5 = df5.drop('REGION', axis=1)
df5 = df5.drop('WORKDAYS', axis=1)
df5 = df5.drop('RPTG_PRD_ENDT', axis=1)
df5 = df5.drop('AVERAGE_PROCESSING_TIME', axis=1)

# %%
df1
# Out:
#      RPTG_PRD_ENDT  FULLY_FAVORABLE               JUDGE   HEARING_OFFICE  \
# 1       04/26/2024            133.0  Abbondondelo, Mary       SHREVEPORT
# 2       04/26/2024             68.0        Able, Devona       ALEXANDRIA
# 3       04/26/2024             76.0    Adamo, Genevieve        CLEVELAND
# 4       04/26/2024             89.0      Adams, Rebecca  FAYETTEVILLE NC
# 5       04/26/2024            143.0     Addison, Andrea      JERSEY CITY
# ...            ...              ...                 ...              ...
# 1394    04/26/2024              2.0     Zanotto, Sharon       HARRISBURG
# 1395    04/26/2024             65.0     Zeidman, Arthur        LAS VEGAS
# 1396    04/26/2024              2.0     Zeidman, Arthur          OAKLAND
# 1397    04/26/2024             78.0    Zimmerman, Stacy           ORANGE
# 1398    04/26/2024             95.0   Zuber, William C.       LOUISVILLE
#
#       PARTIALLY_FAVORABLE  REGION  TOTAL_ALJ_DIPOSITIONS_ACROSS_ALL_OFFICES  \
# ...

# %%
df2
# Out:
#       MONTH    HEARING_OFFICE  HEARING_OFFICE_TIMES_IN_MONTHS  HO_CODE  \
# 1    202404          AKRON OH                             7.0   5380.0
# 2    202404            ALBANY                             9.0   5024.0
# 3    202404       ALBUQUERQUE                             9.0   5077.0
# 4    202404        ALEXANDRIA                             8.0   5075.0
# 5    202404  ATLANTA DOWNTOWN                             8.0   5039.0
# ..      ...               ...                             ...      ...
# 163  202404     VALPARAISO IN                             7.5   5365.0
# 164  202404        WASHINGTON                            11.0   5029.0
# 165  202404      WHITE PLAINS                             8.0   5135.0
# 166  202404           WICHITA                             8.0   5127.0
# 167  202404      WILKES BARRE                             9.0   5037.0
#
#     SITE_CODE
# 1         T1P
# 2         X37
# 3         X12
# 4         X14
# 5         Y13
# ..        ...
# ...

# %%
df3
# Out:
#     RPTG_PRD_ENDT  ALJ_DISPS_PER_DAY_PER_ALJ        HEARING_OFFICE  DISP_RANK  \
# 1      04/26/2024                       2.29           COLUMBIA MO        1.0
# 2      04/26/2024                       2.26           ALBUQUERQUE        2.0
# 3      04/26/2024                       2.26             JOHNSTOWN        2.0
# 4      04/26/2024                       2.15         CHARLESTON WV        4.0
# 5      04/26/2024                       2.15      DALLAS NORTH OHO        4.0
# ..            ...                        ...                   ...        ...
# 158    04/26/2024                       1.10  SPECIAL REVIEW CADRE      157.0
# 159    04/26/2024                       1.09              SAN JUAN      159.0
# 160    04/26/2024                       1.08             MIAMI OHO      160.0
# 161    04/26/2024                       1.02              NEW YORK      161.0
# 162    04/26/2024                       0.97              FLORENCE      162.0
#
#      WORKDAYS
# 1       143.0
# ...

# %%
df4
# Out:
#      AVERAGE_PROCESSING_TIME  CASES_PENDING  DISPOSITIONS  \
# 1                      249.0         2177.0        2057.0
# 2                      361.0         2474.0        1737.0
# 3                      309.0         2699.0        1104.0
# 4                      356.0         1502.0        1774.0
# 5                        NaN            0.0           0.0
# ..                       ...            ...           ...
# 167                    285.0         1310.0        1191.0
# 168                    450.0         2098.0        1654.0
# 169                    294.0         1659.0        1270.0
# 170                    359.0          941.0         666.0
# 171                    396.0         3123.0        1933.0
#
#              HEARING_OFFICE  RECEIPTS
# 1                  AKRON OH    2024.0
# 2                    ALBANY    1582.0
# 3               ALBUQUERQUE    1810.0
# 4                ALEXANDRIA    1136.0
# 5    ANCHORAGE Satellite Of      -1.0
# ...

# %%
df5
# Out:
#              HEARING_OFFICE  AVG_Ptime_RANK
# 1    NATL ADJUDICATION TEAM             1.0
# 2                    TUPELO             2.0
# 3                EVANSVILLE             3.0
# 4             HOUSTON NORTH             4.0
# 5                  AKRON OH             4.0
# ..                      ...             ...
# 159                 OAKLAND           159.0
# 160                SAN JUAN           160.0
# 161       PHILADELPHIA EAST           161.0
# 162                   PONCE           162.0
# 163           SANTA BARBARA           163.0
#
# [163 rows x 2 columns]

# %%
df_main = pd.merge(df5, df2,on='HEARING_OFFICE', how='inner')

# %%
df_main = pd.merge(df_main, df3,on='HEARING_OFFICE', how='inner')

# %%
df_main = pd.merge(df_main, df4,on='HEARING_OFFICE', how='inner')

# %%
st=['09/30/2023']*162
st2=['09/30/2023']*1398

# %%
df_main['RPTG_PRD_STDT'] = st
df1['RPTG_PRD_STDT'] = st2

# %%
df1["Primary"] = df1["JUDGE"] + "-"+ df1["HEARING_OFFICE"]+"-"+ df1["RPTG_PRD_ENDT"]

# %% [markdown]
# #Columns that didnt make it in df_main after inner join

# %%
df2b = df2[~df2['HEARING_OFFICE'].isin(df_main['HEARING_OFFICE'])]
df2b
# Out:
#        HEARING_OFFICE  HEARING_OFFICE_TIMES_IN_MONTHS  HO_CODE SITE_CODE
# 98    NHC ALBUQUERQUE                            14.0   5461.0       T0H
# 99      NHC BALTIMORE                            16.0   5463.0       T0T
# 100       NHC CHICAGO                            14.0   5462.0       T0Q
# 101  NHC FALLS CHURCH                            14.0   5460.0       T0D
# 102      NHC ST LOUIS                            14.0   5464.0       T1U

# %%
df3b = df3[~df3['HEARING_OFFICE'].isin(df_main['HEARING_OFFICE'])]
df3b
# Out:
# Empty DataFrame
# Columns: [RPTG_PRD_ENDT, ALJ_DISPS_PER_DAY_PER_ALJ, HEARING_OFFICE, DISP_RANK, WORKDAYS]
# Index: []

# %%
df4b = df4[~df4['HEARING_OFFICE'].isin(df_main['HEARING_OFFICE'])]
df4b
# Out:
#      AVERAGE_PROCESSING_TIME  CASES_PENDING  DISPOSITIONS  \
# 5                        NaN            0.0           0.0
# 27                       NaN            2.0           0.0
# 95                     154.0            0.0          33.0
# 101                    571.0          521.0        1056.0
# 102                    638.0          932.0        1859.0
# 103                    539.0          579.0        1501.0
# 104                    499.0          715.0        1311.0
# 105                    517.0          725.0        1282.0
# 108                      NaN            3.0           0.0
#
#              HEARING_OFFICE  RECEIPTS
# 5    ANCHORAGE Satellite Of      -1.0
# 27              CREVE COEUR      -1.0
# 95   NATL ADJUDICATION TEAM     -84.0
# 101         NHC ALBUQUERQUE     553.0
# 102           NHC BALTIMORE     197.0
# 103             NHC CHICAGO     569.0
# 104        NHC FALLS CHURCH     396.0
# 105            NHC ST LOUIS     693.0
# ...

# %%
df5b = df5[~df5['HEARING_OFFICE'].isin(df_main['HEARING_OFFICE'])]
df5b
# Out:
#            HEARING_OFFICE  AVG_Ptime_RANK
# 1  NATL ADJUDICATION TEAM             1.0

# %%
df_main
# Out:
#         HEARING_OFFICE  AVG_Ptime_RANK  HEARING_OFFICE_TIMES_IN_MONTHS  \
# 0               TUPELO             2.0                             7.0
# 1           EVANSVILLE             3.0                             7.0
# 2        HOUSTON NORTH             4.0                             7.0
# 3             AKRON OH             4.0                             7.0
# 4         GRAND RAPIDS             6.0                             6.0
# ..                 ...             ...                             ...
# 157            OAKLAND           159.0                            13.0
# 158           SAN JUAN           160.0                            12.0
# 159  PHILADELPHIA EAST           161.0                            17.0
# 160              PONCE           162.0                            17.0
# 161      SANTA BARBARA           163.0                            17.0
#
#      HO_CODE SITE_CODE RPTG_PRD_ENDT  ALJ_DISPS_PER_DAY_PER_ALJ  DISP_RANK  \
# ...

# %%
df1
# Out:
#      RPTG_PRD_ENDT  FULLY_FAVORABLE               JUDGE   HEARING_OFFICE  \
# 1       04/26/2024            133.0  Abbondondelo, Mary       SHREVEPORT
# 2       04/26/2024             68.0        Able, Devona       ALEXANDRIA
# 3       04/26/2024             76.0    Adamo, Genevieve        CLEVELAND
# 4       04/26/2024             89.0      Adams, Rebecca  FAYETTEVILLE NC
# 5       04/26/2024            143.0     Addison, Andrea      JERSEY CITY
# ...            ...              ...                 ...              ...
# 1394    04/26/2024              2.0     Zanotto, Sharon       HARRISBURG
# 1395    04/26/2024             65.0     Zeidman, Arthur        LAS VEGAS
# 1396    04/26/2024              2.0     Zeidman, Arthur          OAKLAND
# 1397    04/26/2024             78.0    Zimmerman, Stacy           ORANGE
# 1398    04/26/2024             95.0   Zuber, William C.       LOUISVILLE
#
#       PARTIALLY_FAVORABLE  REGION  TOTAL_ALJ_DIPOSITIONS_ACROSS_ALL_OFFICES  \
# ...

# %%
df1.columns
# Out:
# Index(['RPTG_PRD_ENDT', 'FULLY_FAVORABLE', 'JUDGE', 'HEARING_OFFICE',
#        'PARTIALLY_FAVORABLE', 'REGION',
#        'TOTAL_ALJ_DIPOSITIONS_ACROSS_ALL_OFFICES', 'TOTAL_AWARDS',
#        'TOTAL_DECISIONS', 'TOTAL_DENIALS', 'TOTAL_DISPOSITIONS',
#        'RPTG_PRD_STDT', 'Primary'],
#       dtype='object')

# %%
df_main.columns
# Out:
# Index(['HEARING_OFFICE', 'AVG_Ptime_RANK', 'HEARING_OFFICE_TIMES_IN_MONTHS',
#        'HO_CODE', 'SITE_CODE', 'RPTG_PRD_ENDT', 'ALJ_DISPS_PER_DAY_PER_ALJ',
#        'DISP_RANK', 'WORKDAYS', 'AVERAGE_PROCESSING_TIME', 'CASES_PENDING',
#        'DISPOSITIONS', 'RECEIPTS', 'RPTG_PRD_STDT'],
#       dtype='object')

# %%
df_main.to_csv('df_main.csv', index=False)

# %%
df1.to_csv('Administrative Law Judge Disposition Data updated.csv', index=False)
